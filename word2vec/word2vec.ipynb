# %%
"""Basic word2vec example."""

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import sys
import argparse
import random
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

from tensorflow.contrib.tensorboard.plugins import projector
# Out:
# /Users/olaf/.pyenv/versions/anaconda3/envs/tfp3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'

# pylint: disable=redefined-outer-name
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  local_filename = os.path.join("./", filename)
  if not os.path.exists(local_filename):
    local_filename, _ = urllib.request.urlretrieve(url + filename,
                                                   local_filename)
  statinfo = os.stat(local_filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception('Failed to verify ' + local_filename +
                    '. Can you get to it with a browser?')
  return local_filename


filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data


vocabulary = read_data(filename)
print('Data size', len(vocabulary))
# Out:
# Data size 17005207

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000


def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    index = dictionary.get(word, 0)
    if index == 0:  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

# %%
# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)
data, count, dictionary, reverse_dictionary = build_dataset(
    vocabulary, vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)  # pylint: disable=redefined-builtin
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  print(buffer)
  data_index += span
  for i in range(batch_size // num_skips):
    context_words = [w for w in range(span) if w != skip_window]
    words_to_use = random.sample(context_words, num_skips)
    for j, context_word in enumerate(words_to_use):
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[context_word]
    if data_index == len(data):
      buffer.extend(data[0:span])
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0],
        reverse_dictionary[labels[i, 0]])
# Out:
# deque([17659, 3400, 24], maxlen=3)
# deque([17659, 3400, 24], maxlen=3)
# deque([3400, 24, 6], maxlen=3)
# deque([24, 6, 5674], maxlen=3)
# deque([6, 5674, 2], maxlen=3)
# 3400 starts -> 17659 schumpeter
# 3400 starts -> 24 with
# 24 with -> 3400 starts
# 24 with -> 6 a
# 6 a -> 5674 treatise
# 6 a -> 24 with
# 5674 treatise -> 6 a
# 5674 treatise -> 2 of

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.
num_sampled = 64  # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

graph = tf.Graph()

with graph.as_default():

  # Input data.
  with tf.name_scope('inputs'):
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    with tf.name_scope('embeddings'):
      embeddings = tf.Variable(
          tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
      embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    with tf.name_scope('weights'):
      nce_weights = tf.Variable(
          tf.truncated_normal(
              [vocabulary_size, embedding_size],
              stddev=1.0 / math.sqrt(embedding_size)))
    with tf.name_scope('biases'):
      nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  # Explanation of the meaning of NCE loss:
  #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
  with tf.name_scope('loss'):
    loss = tf.reduce_mean(
        tf.nn.nce_loss(
            weights=nce_weights,
            biases=nce_biases,
            labels=train_labels,
            inputs=embed,
            num_sampled=num_sampled,
            num_classes=vocabulary_size))

  # Add the loss value as a scalar to summary.
  tf.summary.scalar('loss', loss)

  # Construct the SGD optimizer using a learning rate of 1.0.
  with tf.name_scope('optimizer'):
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings,
                                            valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Merge all summaries.
  merged = tf.summary.merge_all()

  # Add variable initializer.
  init = tf.global_variables_initializer()

  # Create a saver.
  saver = tf.train.Saver()

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # Open a writer to write summaries.
  writer = tf.summary.FileWriter("./logs", session.graph)

  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(batch_size, num_skips,
                                                skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # Define metadata variable.
    run_metadata = tf.RunMetadata()

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    # Also, evaluate the merged op to get all summaries from the returned "summary" variable.
    # Feed metadata variable to session for visualizing the graph in TensorBoard.
    _, summary, loss_val = session.run(
        [optimizer, merged, loss],
        feed_dict=feed_dict,
        run_metadata=run_metadata)
    average_loss += loss_val

    # Add returned summaries to writer in each step.
    writer.add_summary(summary, step)
    # Add metadata to visualize the graph for the last run.
    if step == (num_steps - 1):
      writer.add_run_metadata(run_metadata, 'step%d' % step)

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()

  # Write corresponding labels for the embeddings.
  with open("./" + '/metadata.tsv', 'w') as f:
    for i in xrange(vocabulary_size):
      f.write(reverse_dictionary[i] + '\n')

  # Save the model for checkpoints.
  saver.save(session, os.path.join("./", 'model.ckpt'))

  # Create a configuration for visualizing embeddings with the labels in TensorBoard.
  config = projector.ProjectorConfig()
  embedding_conf = config.embeddings.add()
  embedding_conf.tensor_name = embeddings.name
  embedding_conf.metadata_path = os.path.join(FLAGS.log_dir, 'metadata.tsv')
  projector.visualize_embeddings(writer, config)

writer.close()
# Out:
# Initialized
# Average loss at step  0 :  274.026977539
# Nearest to but: implants, republic, pinning, shogunate, option, bays, spinoff, kimberley,
# Nearest to some: thien, chocolate, famer, vote, seedless, transactional, woe, belarusian,
# Nearest to if: ghats, habitat, timberlake, humanitarians, vlaamse, casas, uninhabitable, broncos,
# Nearest to his: ducas, outlets, spinners, arisen, incorporated, sprinter, guerrillas, equipping,
# Nearest to he: endogamous, lullaby, dz, equipped, tribunes, bf, bartleby, mdf,
# Nearest to known: terminated, imprisoned, fight, ingredients, descended, amathus, deforestation, transfection,
# Nearest to was: moulton, bombardier, member, entrances, frankly, abet, kann, lam,
# Nearest to such: recreationally, cit, milan, fined, veterans, resonated, quack, stamford,
# Nearest to has: fraternities, overhauled, johannine, preoccupied, adolfo, trainees, agathon, bethe,
# Nearest to are: courteous, crowther, harper, intents, picnic, pompous, entrepreneurs, cleft,
# Nearest to would: anarcha, antonine, marital, humber, bodhidharma, typical, flanked, kaufmann,
# Nearest to these: regeneration, shoots, connors, euthanasia, nonsense, primed, mishnah, geisel,
# Nearest to an: guerra, exorbitant, dicaprio, diacritical, independently, hanged, kenny, lexical,
# Nearest to many: sed, kyi, genesee, baserunner, morphological, oldcastle, aft, toole,
# Nearest to see: familias, tariq, canteen, hippolytus, absurdist, rimini, kmt, controversies,
# Nearest to UNK: saturnalia, powerless, platinum, humanities, brutality, walkers, sandinistas, fluke,
# Average loss at step  2000 :  114.341546654
# Average loss at step  4000 :  52.945668035
# Average loss at step  6000 :  33.6134710549
# Average loss at step  8000 :  23.1273606478
# Average loss at step  10000 :  17.7070933815
# Nearest to but: is, david, township, braque, republic, dor, block, ki,
# Nearest to some: the, vote, netbios, figure, riemannian, laboratory, says, moses,
# Nearest to if: plateau, publish, greed, cohen, broncos, pm, cc, equiv,
# Nearest to his: the, township, tanzania, dor, carson, matrix, cc, a,
# Nearest to he: might, who, this, cc, clusters, are, burns, dor,
# Nearest to known: its, place, fight, imprisoned, mtu, drawings, descended, recent,
# Nearest to was: is, has, bombardier, origins, member, catahoula, cc, visions,
# Nearest to such: apology, ghosts, scale, cable, creationism, mars, bibliography, veterans,
# Nearest to has: was, crest, fraternities, is, transferred, by, and, mercenary,
# Nearest to are: is, have, lakes, beautiful, and, be, zero, dsp,
# Nearest to would: typical, and, was, chest, rail, eight, reputation, had,
# Nearest to these: geisel, township, sexual, catahoula, shoots, claude, romanian, sing,
# Nearest to an: postage, independently, dor, a, kenny, capo, z, reign,
# Nearest to many: illusion, significantly, the, township, sloan, features, crush, demons,
# Nearest to see: dvorak, before, and, nova, inter, netbios, splitting, sneaking,
# Nearest to UNK: cc, dor, bar, netbios, one, township, eurocents, and,
# Average loss at step  12000 :  13.9014868083
# Average loss at step  14000 :  11.3209046401
# Average loss at step  16000 :  9.37191108084
# Average loss at step  18000 :  8.82877121985
# Average loss at step  20000 :  8.02750664937
# Nearest to but: and, lagenorhynchus, is, david, ki, braque, block, enya,
# Nearest to some: the, vote, many, netbios, mutants, riemannian, belarusian, these,
# Nearest to if: plateau, publish, greed, for, cohen, blackmore, five, about,
# Nearest to his: the, their, township, salamander, cue, dor, tanzania, s,
# Nearest to he: it, who, this, might, cc, blackmore, have, dor,
# Nearest to known: ingredients, its, place, scriptwriter, fight, imprisoned, terminated, descended,
# Nearest to was: is, has, were, by, had, predominantly, are, visions,
# Nearest to such: reincorporated, creationism, apology, saxons, cable, it, recreationally, bibliography,
# Nearest to has: was, is, had, crest, by, fraternities, and, transferred,
# Nearest to are: is, were, have, beautiful, was, braque, lakes, netbios,
# Nearest to would: writeups, will, had, was, eight, may, typical, and,
# Nearest to these: the, euthanasia, regeneration, their, geisel, sexual, catahoula, some,
# Nearest to an: the, dor, postage, passover, independently, this, dong, wales,
# Nearest to many: illusion, some, lagenorhynchus, the, maslow, crush, significantly, crawl,
# Nearest to see: echidna, dvorak, inter, sneaking, splitting, before, echelon, and,
# Nearest to UNK: cc, dor, digraph, netbios, and, hz, two, kingfisher,
# Average loss at step  22000 :  7.3997616359
# Average loss at step  24000 :  6.86470751798
# Average loss at step  26000 :  6.63483502185
# Average loss at step  28000 :  6.29267244494
# Average loss at step  30000 :  5.97590973377
# Nearest to but: and, lagenorhynchus, is, kiang, enya, ki, braque, block,
# Nearest to some: many, the, these, eon, thien, all, kiang, vote,
# Nearest to if: when, for, greed, plateau, publish, though, is, about,
# Nearest to his: their, the, kiang, township, checksum, dor, her, s,
# Nearest to he: it, who, they, kiang, she, this, cid, ass,
# Nearest to known: ingredients, its, place, scriptwriter, imprisoned, fight, mesopotamia, oblong,
# Nearest to was: is, has, had, were, by, kiang, UNK, visions,
# Nearest to such: bassoon, well, creationism, saxons, apology, reincorporated, cable, known,
# Nearest to has: was, had, is, have, kiang, crest, fraternities, by,
# Nearest to are: were, is, have, eon, kiang, braque, be, was,
# Nearest to would: will, may, writeups, can, could, had, neutronic, to,
# Nearest to these: some, euthanasia, their, eider, sexual, regeneration, monastic, the,
# Nearest to an: the, dor, independently, it, postage, this, nuclear, passover,
# Nearest to many: some, kiang, illusion, maslow, lagenorhynchus, the, all, crush,
# Nearest to see: suzaku, echidna, and, inter, sneaking, echelon, dvorak, before,
# Nearest to UNK: cc, and, dor, netbios, brie, neutronic, hz, one,
# Average loss at step  32000 :  5.72580445433
# Average loss at step  34000 :  5.65304791379
# Average loss at step  36000 :  5.69488882959
# Average loss at step  38000 :  5.49280890298
# Average loss at step  40000 :  5.37788230646
# Nearest to but: and, lagenorhynchus, kiang, brie, it, braque, enya, or,
# Nearest to some: many, these, the, all, any, eon, kiang, thien,
# Nearest to if: when, for, though, greed, plateau, but, publish, is,
# Nearest to his: their, the, kiang, her, s, checksum, its, township,
# Nearest to he: it, they, who, she, kiang, there, this, never,
# Nearest to known: ingredients, such, cooh, scriptwriter, oblong, mesopotamia, its, filking,
# Nearest to was: is, has, had, were, by, kiang, are, be,
# Nearest to such: bassoon, well, saxons, known, creationism, reincorporated, apology, pitts,
# Nearest to has: had, was, is, have, kiang, crest, by, fraternities,
# Nearest to are: were, is, have, eon, was, braque, netbios, be,
# Nearest to would: will, may, can, writeups, could, to, neutronic, had,
# Nearest to these: some, all, the, euthanasia, their, they, monastic, sexual,
# Nearest to an: dor, the, fencer, it, postage, independently, nuclear, pitching,
# Nearest to many: some, kiang, all, the, illusion, maslow, lagenorhynchus, other,
# Nearest to see: and, suzaku, echidna, echelon, sneaking, inter, seclusion, dvi,
# Nearest to UNK: four, cc, five, dor, brie, netbios, three, six,
# Average loss at step  42000 :  5.71935208201
# Average loss at step  44000 :  5.27511710536
# Average loss at step  46000 :  5.22567268777
# Average loss at step  48000 :  5.17127919793
# Average loss at step  50000 :  5.02869288528
# Nearest to but: however, and, lagenorhynchus, szko, kiang, brie, or, it,
# Nearest to some: many, these, all, any, the, several, eon, kiang,
# Nearest to if: when, though, for, greed, plateau, is, publish, but,
# Nearest to his: their, her, the, its, kiang, s, checksum, dor,
# Nearest to he: it, they, who, she, there, kiang, never, cid,
# Nearest to known: ingredients, such, cooh, oblong, mesopotamia, kiang, used, scriptwriter,
# Nearest to was: is, has, were, had, by, be, kiang, became,
# Nearest to such: bassoon, well, known, saxons, pitts, creationism, kiang, include,
# Nearest to has: had, was, is, have, kiang, crest, overhauled, fraternities,
# Nearest to are: were, is, have, eon, kiang, netbios, braque, be,
# Nearest to would: will, can, may, could, writeups, to, neutronic, might,
# Nearest to these: some, all, monastic, they, which, many, euthanasia, their,
# Nearest to an: dor, amdahl, fencer, it, postage, the, independently, untranslated,
# Nearest to many: some, kiang, all, other, these, several, illusion, bacterial,
# Nearest to see: suzaku, echidna, inter, dvi, nei, scroll, echelon, are,
# Nearest to UNK: cc, modula, taunus, szko, glas, netbios, brie, neutronic,
# Average loss at step  52000 :  4.95539865732
# Average loss at step  54000 :  5.08858932605
# Average loss at step  56000 :  5.14408016646
# Average loss at step  58000 :  5.08215951347
# Average loss at step  60000 :  5.00953980243
# Nearest to but: and, however, lagenorhynchus, szko, neutronic, netbios, brie, although,
# Nearest to some: many, these, all, the, any, several, eon, each,
# Nearest to if: when, though, for, greed, plateau, is, but, publish,
# Nearest to his: their, her, its, the, s, kiang, checksum, dor,
# Nearest to he: it, she, they, who, there, kiang, never, blackmore,
# Nearest to known: such, ingredients, used, oblong, cooh, mesopotamia, kiang, well,
# Nearest to was: is, has, were, had, became, kiang, does, by,
# Nearest to such: well, bassoon, known, saxons, pitts, kiang, creationism, include,
# Nearest to has: had, was, have, is, kiang, crest, when, overhauled,
# Nearest to are: were, is, have, be, eon, kiang, netbios, braque,
# Nearest to would: will, can, may, could, writeups, to, might, neutronic,
# Nearest to these: some, all, many, which, their, they, monastic, euthanasia,
# Nearest to an: the, pagerank, dor, amdahl, fencer, independently, untranslated, it,
# Nearest to many: some, several, all, other, kiang, these, rietveld, bacterial,
# Nearest to see: suzaku, and, hippolytus, echidna, seclusion, nei, incapacitated, reaper,
# Nearest to UNK: cc, dor, netbios, modula, taunus, three, galatea, szko,
# Average loss at step  62000 :  4.98956151819
# Average loss at step  64000 :  4.87786667526
# Average loss at step  66000 :  4.76730432248
# Average loss at step  68000 :  4.83024113548
# Average loss at step  70000 :  4.87116082335
# Nearest to but: and, however, lagenorhynchus, although, which, brie, though, szko,
# Nearest to some: many, these, all, several, any, other, eon, kiang,
# Nearest to if: when, though, for, gluten, greed, is, plateau, publish,
# Nearest to his: their, her, its, the, checksum, s, kiang, dor,
# Nearest to he: it, she, they, who, there, never, kiang, blackmore,
# Nearest to known: such, used, ingredients, cooh, oblong, mesopotamia, responsible, well,
# Nearest to was: is, has, were, had, became, by, be, does,
# Nearest to such: well, bassoon, known, pitts, saxons, kiang, creationism, include,
# Nearest to has: had, was, have, is, kiang, when, crest, five,
# Nearest to are: were, is, have, be, eon, kiang, netbios, was,
# Nearest to would: will, can, may, could, to, writeups, might, should,
# Nearest to these: some, many, all, which, they, their, guant, monastic,
# Nearest to an: pagerank, dor, fencer, it, amdahl, linguistics, exorbitant, brevity,
# Nearest to many: some, several, all, these, other, kiang, bacterial, both,
# Nearest to see: incapacitated, suzaku, reaper, hippolytus, and, dvi, echidna, inter,
# Nearest to UNK: taunus, modula, dor, cc, galatea, netbios, szko, socket,
# Average loss at step  72000 :  4.82513082159
# Average loss at step  74000 :  4.83545181155
# Average loss at step  76000 :  4.825346071
# Average loss at step  78000 :  4.76836833739
# Average loss at step  80000 :  4.78789727175
# Nearest to but: however, and, landesverband, although, though, hyi, brie, lagenorhynchus,
# Nearest to some: many, these, all, several, any, other, each, both,
# Nearest to if: when, though, for, is, before, greed, gluten, because,
# Nearest to his: their, her, its, the, s, checksum, dor, kiang,
# Nearest to he: it, she, they, there, who, never, kiang, blackmore,
# Nearest to known: such, used, ingredients, cooh, mesopotamia, oblong, responsible, well,
# Nearest to was: is, has, had, were, became, be, by, hyi,
# Nearest to such: well, bassoon, known, pitts, saxons, many, these, creationism,
# Nearest to has: had, have, was, is, kiang, crest, hafnium, strong,
# Nearest to are: were, is, have, eon, be, netbios, kiang, hyi,
# Nearest to would: will, can, could, may, should, might, to, writeups,
# Nearest to these: some, many, all, they, their, which, those, several,
# Nearest to an: pagerank, the, fencer, grafton, exorbitant, untranslated, dor, hyi,
# Nearest to many: some, several, these, all, other, kiang, peggy, such,
# Nearest to see: incapacitated, and, hyi, reaper, suzaku, hippolytus, but, list,
# Nearest to UNK: hyi, landesverband, modula, galatea, dor, netbios, cc, taunus,
# Average loss at step  82000 :  4.70145920938
# Average loss at step  84000 :  4.75115236616
# Average loss at step  86000 :  4.53277923954
# Average loss at step  88000 :  4.65708902502
# Average loss at step  90000 :  4.73226709187
# Nearest to but: however, and, although, landesverband, though, hyi, bde, netbios,
# Nearest to some: many, these, several, all, the, any, each, other,
# Nearest to if: when, though, for, before, is, because, galatea, landesverband,
# Nearest to his: their, her, its, the, checksum, dor, s, kiang,
# Nearest to he: it, she, they, who, there, never, kiang, blackmore,
# Nearest to known: such, used, ingredients, well, responsible, defined, mesopotamia, cooh,
# Nearest to was: is, has, had, were, became, been, be, by,
# Nearest to such: well, known, bassoon, pitts, these, kiang, saxons, creationism,
# Nearest to has: had, was, have, is, kiang, bde, overhauled, riso,
# Nearest to are: were, have, is, eon, be, risotto, kiang, netbios,
# Nearest to would: will, can, could, may, should, might, must, writeups,
# Nearest to these: some, many, all, they, the, their, those, there,
# Nearest to an: pagerank, dor, exorbitant, untranslated, the, fencer, hyi, amdahl,
# Nearest to many: some, several, these, all, other, kiang, most, various,
# Nearest to see: riso, bde, incapacitated, hyi, but, suzaku, reaper, list,
# Nearest to UNK: bde, hyi, landesverband, modula, cc, netbios, three, seven,
# Average loss at step  92000 :  4.67192700386
# Average loss at step  94000 :  4.63217518103
# Average loss at step  96000 :  4.61196202946
# Average loss at step  98000 :  4.60861179137
# Average loss at step  100000 :  4.36028068602
# Nearest to but: however, and, although, though, landesverband, hyi, neutronic, which,
# Nearest to some: many, these, all, several, any, each, both, other,
# Nearest to if: when, though, for, before, because, is, where, landesverband,
# Nearest to his: their, her, its, the, s, dor, kiang, checksum,
# Nearest to he: it, she, they, who, there, never, kiang, later,
# Nearest to known: such, used, ingredients, defined, well, responsible, mesopotamia, cooh,
# Nearest to was: is, had, were, has, became, does, be, been,
# Nearest to such: well, known, bassoon, these, pitts, many, creationism, kiang,
# Nearest to has: had, have, was, is, kiang, bde, seven, eight,
# Nearest to are: were, have, is, be, eon, kiang, risotto, braque,
# Nearest to would: will, can, could, may, should, might, must, to,
# Nearest to these: some, many, all, those, they, their, several, there,
# Nearest to an: pagerank, exorbitant, fencer, dor, untranslated, buildup, linguistics, brevity,
# Nearest to many: some, several, all, these, other, kiang, most, various,
# Nearest to see: riso, bde, incapacitated, list, hyi, suzaku, reaper, but,
# Nearest to UNK: bde, four, hyi, landesverband, dor, modula, five, three,
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-9c78bc8d5eb3> in <module>()
#      62
#      63   # Save the model for checkpoints.
# ---> 64   saver.save(session, os.path.join(FLAGS.log_dir, 'model.ckpt'))
#      65
#      66   # Create a configuration for visualizing embeddings with the labels in TensorBoard.
#
# NameError: name 'FLAGS' is not defined

# %%
# Step 6: Visualize the embeddings.


# pylint: disable=missing-docstring
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(
        label,
        xy=(x, y),
        xytext=(5, 2),
        textcoords='offset points',
        ha='right',
        va='bottom')

  plt.savefig(filename)


try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt
  # %matplotlib inline  

  tsne = TSNE(
      perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(), 'tsne.png'))

except ImportError as ex:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
  print(ex)
